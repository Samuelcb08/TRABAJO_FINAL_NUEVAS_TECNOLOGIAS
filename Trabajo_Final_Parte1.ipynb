# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuelcb08/TRABAJO_FINAL_NUEVAS_TECNOLOGIAS/blob/main/Trabajo_Final_Parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
info_Personas=pd.read_csv('/content/drive/MyDrive/Personas.csv', sep = ",")

# %%
info_Personas
# Out:
#        id                 Nombre      Apellido                      email  \
# 0       1        Donovan Castree       Castree        dcastree0@yahoo.com
# 1       2          Pia Lassetter     Lassetter        plassetter1@wix.com
# 2       3        Janina Birchett      Birchett  jbirchett2@opensource.org
# 3       4         Devora Gavaran       Gavaran    dgavaran3@indiegogo.com
# 4       5          Hilda Demeter       Demeter          hdemeter4@nba.com
# ..    ...                    ...           ...                        ...
# 995   996          Tobey Overall       Overall   toverallrn@instagram.com
# 996   997           Pepi Siverns       Siverns       psivernsro@blogs.com
# 997   998  Kakalina Brennenstuhl  Brennenstuhl   kbrennenstuhlrp@imdb.com
# 998   999         Cathrine Simic         Simic           csimicrq@ucoz.ru
# 999  1000           Raul Belison       Belison     rbelisonrr@cornell.edu
#
#      Genero      Marca       Color
# 0      Male      Mazda     Crimson
# ...

# %%
info_Personas.shape
# Out:
# (1000, 7)

# %%
info_Personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1000 non-null   int64
#  1   Nombre    1000 non-null   object
#  2   Apellido  1000 non-null   object
#  3   email     1000 non-null   object
#  4   Genero    1000 non-null   object
#  5   Marca     1000 non-null   object
#  6   Color     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
info_Personas.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
info_Personas.head(10)
# Out:
#    id             Nombre    Apellido                       email      Genero  \
# 0   1    Donovan Castree     Castree         dcastree0@yahoo.com        Male
# 1   2      Pia Lassetter   Lassetter         plassetter1@wix.com      Female
# 2   3    Janina Birchett    Birchett   jbirchett2@opensource.org      Female
# 3   4     Devora Gavaran     Gavaran     dgavaran3@indiegogo.com      Female
# 4   5      Hilda Demeter     Demeter           hdemeter4@nba.com      Female
# 5   6  Morton Dalliwater  Dalliwater  mdalliwater5@indiegogo.com        Male
# 6   7        Mikol Cruce       Cruce           mcruce6@globo.com    Bigender
# 7   8         Darrin Rew         Rew              drew7@yale.edu  Polygender
# 8   9  Rossie Pitceathly  Pitceathly    rpitceathly8@yahoo.co.jp        Male
# 9  10        Joice Kayne       Kayne            jkayne9@cnet.com      Female
#
#         Marca       Color
# 0       Mazda     Crimson
# 1      Nissan       Khaki
# 2       Acura      Violet
# ...

# %%
info_Personas.tail(10)
# Out:
#        id                 Nombre      Apellido                          email  \
# 990   991      Marybelle Duffell       Duffell           mduffellri@prlog.org
# 991   992        Atlante Benditt       Benditt    abendittrj@businessweek.com
# 992   993         Duke Wickstead     Wickstead       dwicksteadrk@arizona.edu
# 993   994          Edgardo Pavis         Pavis         epavisrl@csmonitor.com
# 994   995         Fanni Bartosik      Bartosik  fbartosikrm@printfriendly.com
# 995   996          Tobey Overall       Overall       toverallrn@instagram.com
# 996   997           Pepi Siverns       Siverns           psivernsro@blogs.com
# 997   998  Kakalina Brennenstuhl  Brennenstuhl       kbrennenstuhlrp@imdb.com
# 998   999         Cathrine Simic         Simic               csimicrq@ucoz.ru
# 999  1000           Raul Belison       Belison         rbelisonrr@cornell.edu
#
#          Genero          Marca       Color
# 990      Female      Chevrolet      Indigo
# ...

# %%
list(info_Personas['Marca'].drop_duplicates())
# Out:
# ['Mazda',
#  'Nissan',
#  'Acura',
#  'Saturn',
#  'Ford',
#  'Volkswagen',
#  'Ferrari',
#  'GMC',
#  'Toyota',
#  'Isuzu',
#  'Chevrolet',
#  'Lotus',
#  'Mitsubishi',
#  'Dodge',
#  'Cadillac',
#  'Honda',
#  'Mercedes-Benz',
#  'BMW',
#  'Smart',
#  'Volvo',
#  'Kia',
#  'Holden',
#  'Hummer',
#  'Buick',
#  'Bentley',
#  'Lexus',
#  'Daewoo',
#  'Saab',
#  'Plymouth',
#  'Land Rover',
#  'Jeep',
#  'Aston Martin',
#  'Hyundai',
#  'Subaru',
#  'Mercury',
#  'Infiniti',
#  'Lincoln',
#  'Pontiac',
#  'Audi',
#  'Porsche',
#  'Chrysler',
#  'Maybach',
#  'Oldsmobile',
#  'Scion',
#  'MINI',
#  'Jaguar',
#  'Lamborghini',
#  'Studebaker',
#  'Suzuki',
#  'Morgan',
#  'Jensen',
#  'Maserati',
#  'Foose',
#  'Hillman',
#  'Aptera',
#  'Geo',
#  'Rolls-Royce',
#  'Eagle',
#  'Alfa Romeo',
#  'Fillmore']

# %%
list(info_Personas['Color'].drop_duplicates())
# Out:
# ['Crimson',
#  'Khaki',
#  'Violet',
#  'Aquamarine',
#  'Orange',
#  'Goldenrod',
#  'Indigo',
#  'Fuscia',
#  'Blue',
#  'Turquoise',
#  'Yellow',
#  'Purple',
#  'Teal',
#  'Red',
#  'Green',
#  'Maroon',
#  'Mauv',
#  'Pink',
#  'Puce']

# %%
Marca =['Lexus','Hyundai','Lamborghini','Jaguar','GMC','Ferrari','Volkswagen','Ford']

# %%
Marca
# Out:
# ['Lexus',
#  'Hyundai',
#  'Lamborghini',
#  'Jaguar',
#  'GMC',
#  'Ferrari',
#  'Volkswagen',
#  'Ford']

# %%
info_vehiculos = info_Personas['Marca'].isin(Marca)

# %%
info_vehiculos
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Marca, Length: 1000, dtype: bool

# %%
datos_vehiculos = info_Personas[info_vehiculos]

# %%
datos_vehiculos
# Out:
#        id             Nombre    Apellido                          email  \
# 4       5      Hilda Demeter     Demeter              hdemeter4@nba.com
# 5       6  Morton Dalliwater  Dalliwater     mdalliwater5@indiegogo.com
# 7       8         Darrin Rew         Rew                 drew7@yale.edu
# 8       9  Rossie Pitceathly  Pitceathly       rpitceathly8@yahoo.co.jp
# 16     17     Webster Wenman      Wenman          wwenmang@japanpost.jp
# ..    ...                ...         ...                            ...
# 982   983      Jilleen Delle       Delle         jdellera@sitemeter.com
# 984   985      Martino Rayer       Rayer         mrayerrc@wikipedia.org
# 992   993     Duke Wickstead   Wickstead       dwicksteadrk@arizona.edu
# 994   995     Fanni Bartosik    Bartosik  fbartosikrm@printfriendly.com
# 999  1000       Raul Belison     Belison         rbelisonrr@cornell.edu
#
#          Genero       Marca       Color
# 4        Female        Ford      Orange
# ...

# %%
datos_vehiculos.shape
# Out:
# (236, 7)

# %%
datos_vehiculos.index = range(datos_vehiculos.shape[0])

# %%
datos_vehiculos.head(30)
# Out:
#      id              Nombre    Apellido                              email  \
# 0     5       Hilda Demeter     Demeter                  hdemeter4@nba.com
# 1     6   Morton Dalliwater  Dalliwater         mdalliwater5@indiegogo.com
# 2     8          Darrin Rew         Rew                     drew7@yale.edu
# 3     9   Rossie Pitceathly  Pitceathly           rpitceathly8@yahoo.co.jp
# 4    17      Webster Wenman      Wenman              wwenmang@japanpost.jp
# 5    18  Marguerite Capener     Capener         mcapenerh@surveymonkey.com
# 6    22  Alanson Spencelayh  Spencelayh          aspencelayhl@geocities.jp
# 7    32        Deva Aldhous     Aldhous      daldhousv@merriam-webster.com
# 8    35       Tresa Pilgram     Pilgram               tpilgramy@github.com
# 9    37   Novelia Babington   Babington         nbabington10@wikimedia.org
# 10   43       Jeanna Grooby      Grooby            jgrooby16@rakuten.co.jp
# ...

# %%
datos_vehiculos.to_csv('Info_Vehiculos.csv',sep = ',')
